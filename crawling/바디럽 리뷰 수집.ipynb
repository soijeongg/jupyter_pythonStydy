# %%
#바디럽 사이트: https://bodyluv.kr/product/%EB%B0%94%EB%94%94%EB%9F%BD-%EC%BF%A8-%EC%A0%9C%ED%92%88-%EB%AA%A8%EC%9D%8C%EC%A0%84/562/category/1/display/2/#prdReview

# %%
#여기서 리뷰 가져오기
import requests as req
from bs4 import BeautifulSoup as bs

# %%
url = 'https://bodyluv.kr/product/%EB%B0%94%EB%94%94%EB%9F%BD-%EC%BF%A8-%EC%A0%9C%ED%92%88-%EB%AA%A8%EC%9D%8C%EC%A0%84/562/category/1/display/2/#prdReview'

# %%
req.get(url)
# Out:
# <Response [403]>

# %%
#이렇게 403이 뜨면 먼저 url확인 
#근데 이거 쳐도 아무 문제 없으면 header확인

h = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36'}

# %%
res = req.get(url,headers = h)

# %%
soup = bs(res.text,'lxml')

# %%
#이러면 htmi코드 전부 가지고 있음

# %%
data = soup.select('div.review_list_v2__message.js-collapsed-review-content.js-translate-text')
data
# Out:
# []

# %%
#지금은 이렇게 못가져 오는게 맞다 
#리뷰에 누가 더 달면 하나씩 갱신 리뷰 수가 어마어마 하면 서버에게는 굉장히 부담이 된다
#그래서 이럴때에는 ifrmae사용

# %% [markdown]
# ## iframe
#     - 해당하는 페이지에 새로운 페이지를 삽입하는것
#     - 지금 보는 리뷰는 붙여놓은 페이지
#     - 그냥 붙여놓으면 갱신이 아니라 그냥 보여주기만 하면 되기 때문에
#
#         - iframe 태그 : 기존 페이지 내 새로운 페이지 삽입
#         - 방금 봤던 리뷰 페이지는 새로운 페이지 보여만 주고 있음
#          - 그래서 보여만 주고 있는거지 데이터는 따른 공간에 있어서 못 가져온것
#              - iframe의 원래 주소에 접근해서 데이터를 가져와야 한다

# %%
url =' https://review4.cre.ma/bodyluv.kr/products/reviews?product_code=562&iframe_id=crema-product-reviews-2&widget_style=&app=0&parent_url=https%3A%2F%2Fbodyluv.kr%2Fproduct%2F%25EB%25B0%2594%25EB%2594%2594%25EB%259F%25BD-%25EC%25BF%25A8-%25EC%25A0%259C%25ED%2592%2588-%25EB%25AA%25A8%25EC%259D%258C%25EC%25A0%2584%2F562%2Fcategory%2F1%2Fdisplay%2F2%2F&nonmember_token=&secure_device_token=V2134bfaa7e6f5005c6176f13f862fc3294e6ff79021503c086aae5d6932828523267ce9fbb91a1a2f9e69989a10061e22&iframe=1'
res = req.get(url,headers = h)

# %%
soup = bs(res.text,'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width,initial-scale=1.0,maximum-scale=1.0,minimum-scale=1.0,user-scalable=no" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>상품 리뷰</title>
# <link href="https://assets4.cre.ma/latte/assets/pc/application-578223ee960686070b8a2ae8cb3a6426fd06c633a3975c04405ae1f25304bbfe.css" media="all" rel="stylesheet"/>
# <link href="https://assets.cre.ma/m/favicons/crema/v3/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <style type="text/css">
#
#
# body #content {
#   background: transparent;
# }
#
# span.star, span.camera, .sprite_comment {
#   background-image: url(//assets4.cre.ma/p/bodyluv-kr/brand_settings/00/00/00/00/01/sprite/f2ad504b2d261756.png);
# }
#
# i.star {
#   color: #6BBBF7;
# }
#
# i.unstar:before {
#   color: #6BBBF7;
# }
#
#   i.star:before {
#     content: "\f005";
#   }
#
# ...

# %%
soup = bs(res.text,'lxml')
data = soup.select('div.review_list_v2__message.js-collapsed-review-content.js-translate-text')
data
list1 = []
for i in data:
    print(i.text.strip())
    list1.append(i.text.strip())
# Out:
# 올여름은 더더울거라고 하는데 새로운이불과 베개로 정말 시원한 여름나기가 될 것 같아요.
# 아이보리했구요 너무 화이트 아니라서 좋아요 아늑한 느낌이구요 배게커버도 양면이 달라서 좋고 특히 매트는 시원해요 요즘 잠을 제대로 못자는데 이거 깔고 잘잤어요 추천 네이버에 사진리뷰 처음올림 알려드리고싶어서(2022-06-25 13:05:51 에 등록된 네이버 페이 구매평)
# 아이가땀이많은아이인데우선누웠을때너무시원하다고좋아하고,촉감이부드러워서너무좋아해요가벼우면서도 선풍기바람에쉽게날리지않아서배가아플일도없어서좋네요
# 바디럽에서 맨처음마약 토퍼, 쿨이불, 샤워기 등등 이렇게 구매해서 잘 사용하고 있었는데이번 여름 너무 더워 견딜 수 없어쿨 패드도 구매해봤어요!!기존에 쿨이불이 그레이 색이라 쿨그레이로 구매했구요색상은 쏘쿨그레이네여?!ㅎㅎ재질는 쿨이불 소재랑 비슷한데 내부 재질이 메쉬소재 맞나여 그 왜 구멍송송 모양에 바람 슝슝 통하는!?그런 느낌이라 그런지 쿨링이 더 잘 유지 되는것 같아요기존 쿨이불은 보풀도 심하고 처음에만 쿨링이 좋고 (제가 열이많아서) 조금 있으면 이불이  제 열을 흡수 하느라 뜨거워지더라구여 ㅋㅋㅋㅋ근데 쿨 패드는 그런거 없이 열을 갖고 있지 않고송송 너무 시원해요🤍이번 여름 너무 덥고 해서 아빠도 세트로 선물해드릴거에요.+🔥🔥🔥🔥🔥아 그리고 한 가지 아쉬운게 있다면킹 사이즈도 나왔으면 좋겠어요ㅠㅠㅠ🔥🔥🔥🔥🔥
# 참 신기하네요.한쪽은 시원하고 한쪽은 부드럽고, 아이가 땀을너무많이흘려서 구매했는데.. 이불너무좋아해서 만족합니다.양면이 달라서 4계절 모두 사용할수있을듯해여(2022-08-08 16:47:45 에 등록된 네이버 페이 구매평)

# %%
#strip()
#띄어쓰기 계행 공백등 문자의 앞과 뒤에 있는 불필요 한것들을 없애고 출력해준다

# %% [markdown]
# ---
# - 이렇게 첫번째 페이지 말고 모든 페이지의 리뷰를 가지고 싶다
#  - 그럼 버튼을 클릭하는게 가장 좋은 방법(이건 다음주에 할 것임)
#
#  ---
#  ## 그럼 지금은??
#       - 자세히 보면 URL 의 특정 부분이 다르다!
#       이걸 FOR 문에 넣어서 1부터 25까지 넣기

# %%
for i in range(1,6):
    url = f'https://review4.cre.ma/bodyluv.kr/products/reviews?app=0&iframe=1&iframe_id=crema-product-reviews-2&page={i}&parent_url=https%3A%2F%2Fbodyluv.kr%2Fproduct%2F%25EB%25B0%2594%25EB%2594%2594%25EB%259F%25BD-%25EC%25BF%25A8-%25EC%25A0%259C%25ED%2592%2588-%25EB%25AA%25A8%25EC%259D%258C%25EC%25A0%2584%2F562%2Fcategory%2F1%2Fdisplay%2F2%2F&product_code=562&secure_device_token=V2134bfaa7e6f5005c6176f13f862fc3294e6ff79021503c086aae5d6932828523267ce9fbb91a1a2f9e69989a10061e22&widget_env=100&widget_style='
    res = req.get(url,headers = h)
    soup = bs(res.text,'lxml')
    data = soup.select('div.review_list_v2__message.js-collapsed-review-content.js-translate-text')
    for i in data:
        print(i.text.strip())
# Out:
# 올여름은 더더울거라고 하는데 새로운이불과 베개로 정말 시원한 여름나기가 될 것 같아요.
# 아이보리했구요 너무 화이트 아니라서 좋아요 아늑한 느낌이구요 배게커버도 양면이 달라서 좋고 특히 매트는 시원해요 요즘 잠을 제대로 못자는데 이거 깔고 잘잤어요 추천 네이버에 사진리뷰 처음올림 알려드리고싶어서(2022-06-25 13:05:51 에 등록된 네이버 페이 구매평)
# 아이가땀이많은아이인데우선누웠을때너무시원하다고좋아하고,촉감이부드러워서너무좋아해요가벼우면서도 선풍기바람에쉽게날리지않아서배가아플일도없어서좋네요
# 바디럽에서 맨처음마약 토퍼, 쿨이불, 샤워기 등등 이렇게 구매해서 잘 사용하고 있었는데이번 여름 너무 더워 견딜 수 없어쿨 패드도 구매해봤어요!!기존에 쿨이불이 그레이 색이라 쿨그레이로 구매했구요색상은 쏘쿨그레이네여?!ㅎㅎ재질는 쿨이불 소재랑 비슷한데 내부 재질이 메쉬소재 맞나여 그 왜 구멍송송 모양에 바람 슝슝 통하는!?그런 느낌이라 그런지 쿨링이 더 잘 유지 되는것 같아요기존 쿨이불은 보풀도 심하고 처음에만 쿨링이 좋고 (제가 열이많아서) 조금 있으면 이불이  제 열을 흡수 하느라 뜨거워지더라구여 ㅋㅋㅋㅋ근데 쿨 패드는 그런거 없이 열을 갖고 있지 않고송송 너무 시원해요🤍이번 여름 너무 덥고 해서 아빠도 세트로 선물해드릴거에요.+🔥🔥🔥🔥🔥아 그리고 한 가지 아쉬운게 있다면킹 사이즈도 나왔으면 좋겠어요ㅠㅠㅠ🔥🔥🔥🔥🔥
# 참 신기하네요.한쪽은 시원하고 한쪽은 부드럽고, 아이가 땀을너무많이흘려서 구매했는데.. 이불너무좋아해서 만족합니다.양면이 달라서 4계절 모두 사용할수있을듯해여(2022-08-08 16:47:45 에 등록된 네이버 페이 구매평)
# ...

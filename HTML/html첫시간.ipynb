# %%
http
하이퍼 텍스트 : 클릭했을때 다른 곳으로 넘어가는 곳

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
p태그는 가로 영역차지 자동으로 계행 span에는 계행이 없다

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
br = break

# %%
새파일 하면 하고 다시 라이브서버 해야 함 주소 때문에 ㅁ

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
16진법 10까지는 숫자 11부터는 A B C로 할 수 있음

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
여러개를 수정해서 한번에 선택할 수 있는 방법 
바꿀꺼 마우스 클릭

# %%
컨트롤 하고 물음표아래있는 / 쓰면 주석 처리가능
<b>태그 시각적의미의 강조 
<strong>태그 의미적 강조

b와 스트롱의 차이 b는 그냥 공지사항 타이틀 처럼 시각적으로 
스트롱은 의미 있는것

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
ul이든 ol이든 쓰고 안에 li 씀

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
속성값에 type 넣어서 여러가지 가능
근데 ol밖에 못씀

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
속성중에 반드시 쓰여져야 하는 속성 필수 속성

# %%
상위폴더로 가기 ../하면 올라감

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
그냥/ 하면 위에서 부터 출발한다

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
필수속성: 첫번째 보이는 주소

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
그러니까 한열(가로에 담길거만) 같이 넣고 무조건 바뀌면 tr를 넣어라

# %%
같은거면 합치기
<td rowspan ="할 row의 숫자" 이러면 뒤애 오는 병합할꺼ㅡㄴ 아에 데이터에서 빼면됨
<idncolspan =:할 column의 숫자
    티이블에서는 월난 정보를 병합랗 수 잇다

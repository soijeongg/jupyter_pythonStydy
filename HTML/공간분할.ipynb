# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
이런 요소들 안에서도 베너 로그인 기사 이렇게 나눠진다 
이때는 div안에 div를 넣어줘야 한다 
공간을 분할할때는 div사용

# %%
큰뼈대를 와이어프레임으로 보냄 이걸 보고 디자인해서 보냄
html css만 하는 사람을 웹퍼플리셔
단 일러스트를 할 줄 알아야 함

# %%
div 안에 문단을 담당하기 위해 p태그 사용 
그 문단안에서 지정해주기 위해 span태그 사용

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
p태그는 자동으로 계행 웹페이지의 공간을 모두 차지하는 속성을 가지고 있음
이게 p태그 만의 고유한 속성이 아니라 디스플레이속성이 블락이여서 공간을 모두 차지하고 있는 것

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
내가 준 컨텐츠 너비만을 저라룰 차지한다
그래서 너비와 높이를 설정헐 수 없다

# %%
p태그 문단 paragraph의 줄임말 그래서 문단처럼 표현

# %%
p태그 인라인 요소인 애들한테는 높이(height)넓이(width) 사용가능
근데 여기 px안 붙어주면 말 안듣는다

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
이렇게 ,사용해 동일한 속성이면 둘이 같이 한 선택자로 쓰고 사용이 가능하다

# %%
 display속성은 기본값 block */
        /* 무조건 한줄 전체 차지 width, height 사용가능*/
        /* display : inline */
        /* 내가 담은 컨텐츠 까지만 크기로 삼는 속성 width, height 사용불가*/
        /* 대신 이 기본값을 바꿀 수도 있다 */

# %%
display가 인라인 블락인 친구는 인라인과 블락의 중간지점
요새는 flex가 많이 쓰임
display: none 안보이게 하기 
    그러면 아예 안보인다
    
이제 할거 마우스를 올리면 보이게 hover속성()

# %%
클래스위에 마우스를 올리면 호버 바로 앞에 있는 근접 후행 class가 answer인 애들을 선택

# %%
   .question:hover+.answer{
            display: block;

        }

# %%
none이면 있는데 안보이는것

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

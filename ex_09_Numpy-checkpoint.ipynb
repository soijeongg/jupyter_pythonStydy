# %%
# 파이썬 라이브러리(모듈)
#데이터를 분석하는데 용이한 모듈들을 배움
#그중 하나가 NUMPY
#모듈마다 특징이 있어서 그것들을 가지고 와서 안에 어떤 개념들이 있는지 알아보고 
#실습도 해봄
#C드라이브 유저 쥬피터 들어가면 바로 나옴
#모듈을 사용할려고 하면 모듈과 같은위치에 사용할 파일이 있어야 함

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

# %%
#리스트 튜플 딕셔너리  = 자료구조
#자료구조는 여러가지 값을 저장하는데 목적이 있다
#numpy내부의 자료구조가 존재한다 이걸 array라고 부름
#array는 연산에도 목적이 있다

# %%
list1 = [1,2,3]
list2 = [4,5,6,]
list1+list2
#리스트는 저장에 목적이 있지 연산이 목적이 아니라서 그냥 이어붙여지는것

# %%
np.array(list1)+np.array(list2)

# %%
#numpy안에 있는것들을 사용할려면 자료구저가 array인것들만 사용(보통은)
#array 만드는 방법(변환하기의 느낌이 조금 더 크긴 함)
#1.리스트로 저장할 값 정리하기
list1 = [1,2,3,4,5]
#2. list를 array로 변환하기
arr1 = np.array(list1)

# %% [markdown]
# - 안에 들어있는게 리스트 이긴 하지만 애는 array 안에 있는 리스트 인것
# - 나중에는 만들어져 있는거를 계산에 용이한 numpy로 만듦
# - 근데 그러면 이걸 파악하기가 힘듬

# %%
list2 =[[1,2,3],[4,5,6]]
arr2 = np.array(list2)
arr2

# %%
#array 정보 출력하기
#배열의 크기(모양)
arr2.shape #2차원리스트 중 3개씩
#차원:데이터 하나가 얼마나 많은 리스트로 감싸져 있는가 []가 1개씩
#(높은차원의 개수, 낮은차원의 개수) 1차원 자체 2개[1,2,3], [4,5,6] 이 2개 모여 2차원

# %%
#배열의 데이터 갯수
arr2.size
#배열의 차원(차원 그자체만 보여줌)
arr2.ndim

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
list2 = [[[1,2],[3,4]],[[5,6],[7,8]]]
arr= np.array(list2)
print(arr)
print("배열의 크기 :", arr.shape)
print("배열의 차원 :", arr.ndim)
print("배열의 개수 :", arr.size)

# %%
#근데 이게 shape가 (2,2,2) 여서 1치원 갯수가 2개 그리고 그 2개씩 들어있는 리스트 모여
#2차원 2개씩의 리스트를 만든다
#그 3차원 리스트가 2개여서 (2,2,2)가 된다

#이건(2,,3,2) 리스트가 의미없이 그냥 닫히고 열리면 에러
list2 = [[[1,2],[3,4],[5,6]]]
arr = np.array(list2)
arr.shape

# %% [markdown]
# ## 행또는 열의 길이가 다른 배열은 정의가 가능한데 에러뜬다

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#배열의 생성: np.zeros(배열의 크기)>배열의 초기화
np.zeros((3,4))

# %%
#배열의 초기화
np.ones((3,4))

# %%
#원하는 값으로 배열 생성하기np.full(배열의 크기, 원하는 값)
np.full((3,4),7)
#앞이 2차원 3개 뒤가 1차원 4개를 7로 만듬

# %%
#함수의 이름을 외우지는 말라 함수의 기능을 기억해라

# %%
#순서가 있는 값으로 배열을 생성하기 (1,2,3,4,5) 이런식
#np.arang(시작숫자, 끝숫자+1, 간격)

# %%
arr = np.arange(1,51)
print(arr)

# %%
#랜덤값으로 만들기
#랜덤 값의 범위가 0부터 1까지 실수 값으로 만들기
#np.random.rand(배열의 크기 괄호 없이)
np.random.rand(2,3)

# %%
#랜덤값으로 만들기 원하는 범위의 숫자 안에서 랜덤으로 만들기
#np.random.randint(범위의 첫숫자, 범위이 마지막 숫자+1, size = 배열의 크기)
#정수의 값으로 랜덤하게 만들어준다
np.random.randint(2,10, size = (2,3))

# %%
#0부터 10까지 랜덤한 실수값이 담긴 배열 크기 3,2

# %%
#애초에 실수로 랜덤이 없으니까 더하기
arr1 = np.random.randint(0,10 ,size = (3,2))
arr2  = np.random.rand(3,2)
arr1+arr2

# %%
 np.random.rand(3,2)*10

# %%
#배열에서 원하는 값 가져오기
#전체를 대상으로 할수도 있지만 내가 원히는 값만 꺼내올 수 있음

# %%
#0~49까지의 값이 담긴 배열
#기존의 인덱싱과 슬라이싱이 가능
#배열도 순서가 있는 자료의 구조 
arr3 = np.arange(0,50)
arr3

# %%
#하지만 그러면 2차원일때는 어떻게 하면 좋을까?
#.reshape(변경될 크기)
#reshape 전과 후의 데이터 크기가 동일해야 한다 
arr3 = arr3.reshape(5,10)

# %%
#2차원 배열에서 원하는 값 출력하기
#인덱싱 슬라이싱사용 차원별로 생각을 해야함
#1차원 데이터에서 인덱싱 번호, 2차원데이터에서 인덱싱번호

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 2차원을 기준으로 했을때 arr3[2차원 인덱스값, 1차원인덱스값]
#슬라이싱도 가능
#차원이 늘어나게 되도 높은 차원이 앞에 가고 1이 끝
arr3[2,4]
arr3[1,2:5]
#맨 처음 숫자 가장 높은 차원에서 가장 첫번째 것을 가지고 오겠다
#그래서 여기 10부터 19까지에서 2~4번째 가져옴

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
arr3[0:4,0:5]

# %%
arr4 = arr3[0:5,0].reshape(5,1)
arr4

# %%
arr3[1:4,2:5]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
#txt파일을 array형식으로 받아오기
data = np.loadtxt("data/height_weight.txt",delimiter = ",")

keyss =[]

weight = data[1]
height = (data[0]/100)

bmi = weight/(height**2)
    
    
    
for i in range(10):
    keyss.append( data[1][i]/((data[0][i]*0.01)*(data[0][i]*0.01)))
array_for = np.array(keyss)
print(array_for)




ans = (data[0]*0.01)*(data[0]*0.01)
data[1]/ans
# Out:
# [21.37153104 27.07018468 25.86122449 24.20652885 16.03543423 20.14486193
#  23.14392095 21.69720651 23.62028791 25.59220998]
# array([21.37153104, 27.07018468, 25.86122449, 24.20652885, 16.03543423,
#        20.14486193, 23.14392095, 21.69720651, 23.62028791, 25.59220998])

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#boolean indexing
#기존에는 인덱싱 범위를 사용해서 가져오거나 여러가지 가져오고 싶으면 슬라이싱
#원하는 값이 인덱싱 번호여야 한다는 단점이 있다
#25보다 큰값을 가지고 오고 싶#어
arr6 = np.array([1,4,2,3,5])
#3이상만 출력하기
#이렇게 되면 인덱싱 값에 맞지 않는 것은 출력이 안되고 True인것만 출력이 된다
#결과값이 boolean이여야 하고 모든 데이터를 표현(다른게 섞이면 안됨)
arr_3 = arr6[arr6>=3]
arr_3
# Out:
# array([4, 3, 5])

# %%
#bmi에서 키가 170 이상인 사람의 bmi구하기
height = data[0]
data_170 = data[0,height>=170]/100
data_1702 = data[1,height>=170]
over_bmi = data_1702/(data_170**2)
over_bmi
# Out:
# array([21.37153104, 27.07018468, 25.86122449, 16.03543423, 20.14486193,
#        23.14392095, 21.69720651, 23.62028791, 25.59220998])

# %%
#값 인덱싱 해서 찾기 근데 넘파이는 인덱싱 함수가 안되니까 np.where함수사용해 인덱싱
height = data[0]
weight = data[1]
data_170 = height[height>=170]
#170넘는 것들의 인덱싱 번호 받아서 인덱싱 하기
weight=weight[np.where(height>=170) ] 
weight/(data_170/100)**2
# Out:
# array([21.37153104, 27.07018468, 25.86122449, 16.03543423, 20.14486193,
#        23.14392095, 21.69720651, 23.62028791, 25.59220998])

# %%
#기준이 무엇인지 
#데이터의 갯수와 순서가 같은지
#그럼 불린데이터와 적용시킬 데이터가 달라도 상관없다

# %%
#a에서 b까지 사이즈 2*5로랜덤숫자 뽑기
#그냥 sum함수와 다르게 넘파이의 sum함수는 축변경(axis =0 axis = 1이 가능)
#1이면 가로 0이면 세로 끼리만 더해진다(차원별로만 계산이 가능하다)
rand = np.random.randint(1,10,size = (2,5))
np.sum(rand)
np.mean(rand,axis =0)
#mean은 평균값
# Out:
# 44

# %% [markdown]
# # 다른 배열간에 연산 필요 없음 하나만 있으면 됨
# ![image.png](attachment:image.png)

# %% [markdown]
# # 서로 다른 배열간에 사용하는 함수
# ![image.png](attachment:image.png)

# %%
# ::두개로 구분 첫번째 아이디 2번쨰 영화의 id 3번째가 평점 마지막 시간(이건 안써서 없다고 해도 됨)
#1 :: 1193 :: 5
#이건 1번 유저가 1193번 영화에 대해 5점  평점

# %%
np.__version__
# Out:
# '1.23.5'

# %%
#이것도 text파일을 불러오는것, delimiter 구분점 데이터 타입 int
data = np.genfromtxt("data/ratings.txt", delimiter = "::",dtype = 'int')
data
# Out:
# array([[        1,      1193,         5, 978300760],
#        [        1,       661,         3, 978302109],
#        [        1,       914,         3, 978301968],
#        ...,
#        [     6040,       562,         5, 956704746],
#        [     6040,      1096,         4, 956715648],
#        [     6040,      1097,         4, 956715569]])

# %%
#일정 갯수가 넘으면 생략이 되기떄문에 data.shape 사용
data.shape
#2차원에는 1000 얼마가 있고 1차원에는 4개씩 있다 1차원 리스트 하나에 있는거
# Out:
# (1000209, 4)

# %%
#1.전체(10000209)명의 평점 평균 구하기
lisr = []
for i in range(1000209):
    lisr.append(np.mean(data[i][2]))
print(np.mean(lisr))

#그냥 처음부터 가지고 오고 싶으면 : 사용하기
# Out:
# 3.581564453029317

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
bol = data[ : , 0:1] == 1
bol
ss= data[:,2][bol]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[151], line 3
#       1 bol = data[ : , 0:1] == 1
#       2 bol
# ----> 3 ss= data[:,2][bol]
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
#2. 1번 사람의 평점 평균 구하기
yours = []
for i in range(1000209):
    if data[i,0]==1:
        yours.append(data[i,2])
np.mean(yours)
# Out:
# 4.188679245283019

# %%
bol = data[:,0]==1
rating = data[bol,2]
np.mean(rating)
# Out:
# 4.188679245283019

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#3번 모든 사람의 평점 평균 구하기
#값을 리스트에 저장하기
mmm_list1 = []
mmm_list2 = []
mmm_list3 = []
mmm_list4 = []
mmm_list5 = []
the_last = []
for i in range( 1000209):
    if data[i,0]==1:
         mmm_list1.append(data[i,2])
    elif data[i,0]==2:
        mmm_list2.append(data[i,2])
    elif data[i,0]==3:   
        mmm_list3.append(data[i,2])
    elif data[i,0]==4: 
        mmm_list4.append(data[i,2])
    elif data[i,0]==5:
        mmm_list5.append(data[i,2])
num1 = np.mean(mmm_list1 )
num2 = np.mean(mmm_list2 )
num3 = np.mean(mmm_list3 )
num4 = np.mean(mmm_list4 )
num5 = np.mean(mmm_list5 )
the_last.append([1,num1])
the_last.append([2,num2])
the_last.append([3,num3])
the_last.append([4,num4])
the_last.append([5,num5])
the_last
# Out:
# [[1, 4.188679245283019],
#  [2, 3.7131782945736433],
#  [3, 3.9019607843137254],
#  [4, 4.190476190476191],
#  [5, 3.1464646464646466]]

# %%
#1번 2번을 반복문해서 전체 받아오기
total_list = []
for i in range(1,6041,1):
    bol = data[:,0]==i
    rating = data[bol,2]
    mean_rating = np.mean(rating)
    total_list.append([i,mean_rating])
total_list
# Out:
# [[1, 4.188679245283019],
#  [2, 3.7131782945736433],
#  [3, 3.9019607843137254],
#  [4, 4.190476190476191],
#  [5, 3.1464646464646466],
#  [6, 3.9014084507042255],
#  [7, 4.32258064516129],
#  [8, 3.884892086330935],
#  [9, 3.7358490566037736],
#  [10, 4.114713216957606],
#  [11, 3.2773722627737225],
#  [12, 3.8260869565217392],
#  [13, 3.388888888888889],
#  [14, 3.32],
#  [15, 3.3233830845771144],
#  [16, 3.0285714285714285],
#  [17, 4.075829383886256],
#  [18, 3.6491803278688524],
#  [19, 3.5725490196078433],
#  [20, 4.083333333333333],
#  [21, 2.909090909090909],
#  [22, 3.0673400673400675],
#  [23, 3.3157894736842106],
#  [24, 3.948529411764706],
#  [25, 3.7411764705882353],
#  [26, 2.96],
#  [27, 4.171428571428572],
#  [28, 3.7570093457943927],
#  [29, 3.5833333333333335],
#  [30, 3.488372093023256],
#  [31, 3.73109243697479],
#  [32, 3.625],
#  [33, 3.498721227621483],
#  [34, 3.8658536585365852],
#  [35, 3.54040404040404],
#  [36, 4.199430199430199],
# ...

# %%
#각사용자별 평균평점이 4잠이상인 사용자 구하
3기
total_np = np.array(total_list)
    
total_np[:,1]>=4
total_np[total_np[:,1]>=4,0].astype (int
# Out:
# array([   1,    4,    7, ..., 6027, 6032, 6034])

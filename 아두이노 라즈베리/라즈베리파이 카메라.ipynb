# %% [markdown]
# # 굉장히 연약 하니까 조심

# %% [markdown]
# = 메뉴 기본 성정
# ![image.png](attachment:image.png)

# %% [markdown]
# #performancce로 가서 256
# - 원래 있었는데 카메라 포트 사라지 ㅁ그래서 컨트롤 알트 티 하고 터미널 열기
# - 카메라도 정착할려면 전원크고 전류 끄고 함

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#가격 대비 화질이 10080 인데 내구성이 엄청 낮다 유연한 케이블

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#근데 프로젝트에는 이것보다 웹캠을 유에스비 포트에 넣어서 쓰면 좋음

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#ras 라즈베리파이 still스틸샷 -o 아웃풋 tsest

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# -t timeout이 밀리세컨드 단위 기본 5초

# %%
#반복문 사용해 5초마다 사진찍긱

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#picamera로 설치해 진행

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#os는 터미널에서 쓰는 것 과 똑같은 효과

# %%
#motion 설치  sudo nano nano 편집기

# %%
로컬호스트 온 하면 다른 아이피 아예 안됨

# %%
motion 설치해서 동작감지
근데 이거 red box 사용해서  나오게
sudo start mption stop sudo service motion start 하기
그리고 이걸 streamport 하면 스크리밍 화면 볼 수 있음

# %% [markdown]
# ![image.png](attachment:image.png)

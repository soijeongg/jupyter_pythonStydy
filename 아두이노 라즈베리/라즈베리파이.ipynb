# %% [markdown]
# - hdmi 꼽고 옆에 C핀 마우스와 키보드 필요한
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - 플라스크 서버 올리기
# - @app route 경로 분석
# - 이 index 안은 htmi 로
# - 내가 직접 run하게 되면 __name__이 __main__으로 바뀌지만 내가 안하면 안바뀜
# ![image.png](attachment:image.png)

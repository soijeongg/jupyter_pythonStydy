# %%
#앙상블
#성능이 잘나온다(다른거와 비교했을때)

# %% [markdown]
# ## 1. 문제정의
# - 유방암 데이터셋을 사용해서 암을 분류해보자

# %% [markdown]
# ## 2. 데이터 수집

# %%
from sklearn.datasets import load_breast_cancer

# %%
cancer = load_breast_cancer()

# %%
cancer.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %% [markdown]
# ## 3. 데이터 전처리

# %%
#학습용이여서 안해도 됨

# %% [markdown]
# ## 탐색적 데이터 분석

# %%
#학습용이여서 안해도 됨

# %% [markdown]
# ## 5. 모델선택 및 하이퍼 파라미터 튜닝
# - 1.X_train, X_test, y_train ,y_test 만들기
# - 2.KNN, Decision Tree 모델 불러오기
# - 3. 하이퍼 파라미터 튜닝 해보기

# %%
#데이터 나누기
X =cancer['data']
y =cancer['target']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test =train_test_split(X,y, test_size =0.3,
                                                  random_state =6)

# %% [markdown]
# ## 6. 학습
# KNN Decision Tree 모델에 학습하기

# %%
from sklearn.neighbors import KNeighborsClassifier
knn =KNeighborsClassifier()

# %%
knn = KNeighborsClassifier(n_neighbors =6, p=1,weights ='distance')

# %%
dt =DecisionTreeClassifier(max_depth = 5)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=6, p=1, weights='distance')

# %%
knn.score(X_train,y_train)
# Out:
# 1.0

# %%
knn.score(X_test,y_test)
# Out:
# 0.9532163742690059

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(knn,X_train,y_train,cv=5)
# Out:
# array([0.9375    , 0.9       , 0.9125    , 0.87341772, 0.93670886])

# %%
cancer['data']
# Out:
# array([[1.799e+01, 1.038e+01, 1.228e+02, ..., 2.654e-01, 4.601e-01,
#         1.189e-01],
#        [2.057e+01, 1.777e+01, 1.329e+02, ..., 1.860e-01, 2.750e-01,
#         8.902e-02],
#        [1.969e+01, 2.125e+01, 1.300e+02, ..., 2.430e-01, 3.613e-01,
#         8.758e-02],
#        ...,
#        [1.660e+01, 2.808e+01, 1.083e+02, ..., 1.418e-01, 2.218e-01,
#         7.820e-02],
#        [2.060e+01, 2.933e+01, 1.401e+02, ..., 2.650e-01, 4.087e-01,
#         1.240e-01],
#        [7.760e+00, 2.454e+01, 4.792e+01, ..., 0.000e+00, 2.871e-01,
#         7.039e-02]])

# %% [markdown]
# ## 7. 평가 및 예측
# - 기본평가, 교차 검증 사용해보기

# %%
# tree 모델에 학습시키기

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
tree = DecisionTreeClassifier()

# %%
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
tree.score(X_train, y_train)
# Out:
# 1.0

# %%
tree.score(X_test,y_test)
# Out:
# 0.9181286549707602

# %%
#교차검증

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(tree,X_train,y_train, cv=5).mean()
# Out:
# 0.9372784810126582

# %%
#앙상블 계열의 모델
#bagging Boosting
#성능이 잘나온다

# %%
#앙상블의 RandomForest
#랜덤성을 활용해 Decision Tree여러개 사용하기

# %%
#Decision Tree는 과대적합이 잘걸려서 잘 안씀
#서로 다른 Decision Tree를 만들어서 합친다 합칠꺼면

# %%
#앙상블의 RandomForest
#랜덤성을 활용해 Decision Tree여러개 사용하기
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=150, max_features=0.5)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_features=0.5, n_estimators=150)

# %%
rf.score(X_test,y_test)
# Out:
# 0.9649122807017544

# %%
rf.score(X_train,y_train)
# Out:
# 1.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
서로 다른 디시젼 트리를 여러개 모아 한번에 통계를 내는게 랜덤 포레스트
디시젼 트리는 가장 잘 분류 할 수 있는 질문을 맨 처음함 그래서 이걸 다른 질문 을하게 해줘야 함

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
무작위: 부트스트랩, 복원추출
    - 사용하는 디시젼 트리마다 다른 데이터셋을 사용할 수 있도록 함
    - 복원추출 내가 있는 데이터의 수만큼 랜덤으로 추출하는데 중복을 허용함
    - 중복을 허용해서 하게 하면 69.4%의 데이터가 랜덤하게 들어감
    - 랜덤하게 뽑은건 알겠는데 그들어있는게 비슷한ㄷㅔ?(행만 랜덤아니야?)
        - 여기서 노드의 기준이 되는 특성을 무작위로 선택하게 된다(열도 랜덤!)
    - 기본으로 가지고 있는게 100개씩 만듬!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
회귀- 평균치 사용
분류기준으로 다수결의 원칙을 사용해서 위험이 더 많으니까 위험으로 표현

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %%
#이런식으로 하이퍼파라미터를 튜닝해서 값을 높게 한다

# %%
#그리도 서치 
#사용가능한 매개변수의 모든 조합을 시도해보는것
#RandomForest max_features n_estimtors  등 매개변수 값을 리스트로 만들어서 이중 하나씩 해보라고 하는것

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
이렇게 해두면 알아서 가능한 모든 조합을 해주고 최적의 결과는 어떤 하이퍼파라미터를 쓸때인지
그때 최적의 값이 얼마였는지 알려줌

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_param = {'max_features':[0.4,0.5,0.6,0.7],
             'n_estimators':[50,100,150,200],
             'max_depth': [4,5,6,7,8],
             'max_leaf_nodes':[300,400,500,600]}

# %%
grid_search = GridSearchCV(RandomForestClassifier(),grid_param,cv=5) # 320가지의 가짓수에 5번 하는거

# %%
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [4, 5, 6, 7, 8],
#                          'max_features': [0.4, 0.5, 0.6, 0.7],
#                          'max_leaf_nodes': [300, 400, 500, 600],
#                          'n_estimators': [50, 100, 150, 200]})

# %%
#어떨때 가장 최적의 결과가 나왔는지
grid_search.best_estimator_
# Out:
# RandomForestClassifier(max_depth=6, max_features=0.5, max_leaf_nodes=600,
#                        n_estimators=50)

# %%
grid_search.best_score_
# Out:
# 0.9648417721518987

# %% [markdown]
# ## 앙상블의 부스팅
# -GrandientBoosting Decision Tree를 여러개 사용한다
# - Bagging은 합쳐서 여러개 사용하지만 이건 하나의 Tree를 여러번 발전 시킨다

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
처음부터 잘하기 보다는 그냥 대출 분류시킴
그럼 맞춘게 있고 틀린게 있음
- 맞은걸 제쳐 두고 틀린것들 위주로 선 그음

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
맞춘것들은 가중치를 낮게 하고 틀린것들은 가중치를 높게함(모델에 많이 반영함)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
한번 분류할려 할때마다 Tree를 하나씩 쓴다

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#ensable -addBooest
#Decision Tree 여러개 연결해서 사용하기
from sklearn.ensemble import AdaBoostClassifier
ada =AdaBoostClassifier()

# %%
ada.fit(X_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
ada.score(X_train, y_train)
# Out:
# 1.0

# %%
ada.score(X_test, y_test)
# Out:
# 0.9590643274853801

# %%
cross_val_score(ada,X_train, y_train, cv=5 ).mean()
# Out:
# 0.9649050632911391

# %% [markdown]
# ## 장점

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
비교적 빠르다 : 실제로 100개만큼은 걸리지 않는다 얉은걸 여러개 만든다
위는 예측 다음은 학습(다 알아보고 해야 하기때문에 학습이 더 느리다 )
knn같은 모델들은 거리와 관련있어 지정을 해줘야 하지만 Decision Tree기반은 컬럼별로 따로 해서 조정 안해줘도 됨
단점: 희소한 고차원 데이터에 잘 동작하지 않음

# %%
#특성의 중요도 확인이 가능하다
#자주 나오는 질문들이 있어 어떤 질문이 자주 쓰었고 그런걸 알 수 있어 이걸 기반으로 특성의 중요도 계산

# %%
#전체 특성 중요도의 합이 1이다 
#이 중요도를 1로 두고 분배한 것이다  근데 어떤 숫자가 뭔지는 모른다
#들어가는 시간(예측시간)을 줄일 필요가 있다 --> 데이터의 양 줄이기
#별로 쓸모없는 데이터 같아도 혹시 몰라서 넣었다 이러면 생각 할게 많아지고 규칙이 많아짐
#양을 줄일때 중요도가 낮은 데이터 부터 삭제 
#일부로 과소적합쪽으로 이동
rf.feature_importances_
# Out:
# array([0.00520361, 0.01988371, 0.00304286, 0.00878561, 0.00478024,
#        0.00272726, 0.01014731, 0.07783963, 0.00149127, 0.00228   ,
#        0.00524749, 0.0031549 , 0.00530822, 0.02885445, 0.00225075,
#        0.00288405, 0.00425222, 0.00288824, 0.00349435, 0.00437224,
#        0.09825956, 0.01777256, 0.2098049 , 0.10115177, 0.00915647,
#        0.00540384, 0.00678154, 0.34207765, 0.00450654, 0.00619676])

# %%
cancer.feature_names
# Out:
# array(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error',
#        'fractal dimension error', 'worst radius', 'worst texture',
#        'worst perimeter', 'worst area', 'worst smoothness',
#        'worst compactness', 'worst concavity', 'worst concave points',
#        'worst symmetry', 'worst fractal dimension'], dtype='<U23')

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import numpy as np 
# 축 번호별로 중요도 그래프를 그림
plt.barh(range(30), rf.feature_importances_)
# 축 번호에 축 이름을 출력
plt.yticks(np.arange(30), cancer.feature_names)
plt.xlabel("attr importances")
plt.ylabel("attr")
plt.ylim(-1, 30)# y축의 범위조정
plt.show()

# %%
sns.countplot()
plt.barh(range(30), rf.feature_importances_)
# 축 번호에 축 이름을 출력
plt.yticks(np.arange(30), cancer.feature_names)
plt.xlabel("attr importances")
plt.ylabel("attr")
plt.ylim(-1, 30)
plt.show()
plt.show()

# %%
import pandas as pd
import seaborn as sns
seaborn_df = pd.DataFrame([list(rf.feature_importances_),list(cancer.feature_names)])
#데이터프레임으로 중요도 별로 나눈것과 이름을 리스트로만듬 근데 이렇게 만들면 가로로 이루어짐
#이걸 trance로 돌리기
seaborn_df = seaborn_df.T
#barplot에 data로 넣고 이름 넣기
sns.barplot(data = seaborn_df, x = 0 , y = 1)
# Out:
# <Axes: xlabel='0', ylabel='1'>

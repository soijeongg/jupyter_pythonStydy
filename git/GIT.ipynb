# %% [markdown]
# ![image.png](attachment:image.png)

# %%
막상 조금씩 디테일이 다를 수 있어 하나의 프로젝트를 두고 병렬적으로 프로그램 진행 할 수 있도록 도와줌

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
온라인 상에서 도와주는 사이트
git이라는 명령어를 써서 github에 올림

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
올리는것 PUSH 내려받는것 PULL 보안에 치명적인 단점
github: remote repository
    local repository 에 있는 것만 반영해 push full 함
    commit을 반드시 해줘야 함

# %%
만들고 commit하고 다른 사람들이 전에 올린것과 합쳐야 하기 때문에 pull 해줘야 함
다른 사람이 바꾼 내용을 먼저 받고 정리한 다음에 올려야 함
pull-->commit --> pull -->commit -->push

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
같은 파일에 같은 이름을 가진 이름을 가진 파일이 내용이 다를떄 충돌이 발생, 해결은 할 수 있지만
시간이 늦어짐
충돌을 예방하기 위해 
꼭  commit먼저하고 push pull 하기

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
메인페이지 가는 방법: 좌측 상단에 메뉴버튼 누르면 home아러고 있음
    거기에서 내 프로필

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
remote repository 원격저장

보안 문제가 있을 수 있다.

local repository = 깃허브에서 접근할 수 있는 공간 만들기.

commit : 수정된 코드를 로컬레퍼지토리에 반영

①commit - pull(깃허브 절차문제때문에, 누가 먼저 올렸을 수도 있으니까!)

②commit- push

개인 repo - https://github.com/fiatluxdaisy/myrepo.git

cd : 경로 바꾸기

cd 바꾸고 싶은 경로

ls 현재 접근 가능한 경로 표시

붙여넣기 shift+insert

tab : 자동완성

0.경로 맞추기

1.git init :현재 폴더를 로컬 레퍼지토리화 시키겠습니다

- -->프로젝트 맨처음 시작

2.사용자 정보 등록

git config -- global user.neme “사용자 이름”

git config -- global user.email “사용자 이메일”

3. git remote add origin 원격저장주소(레퍼지토리 주소)

4.git add .

- ->커밋 준비
- -> . : 현재 경로에 있던

5. git commit -m "커밋 메세지"

- -> 커밋 진행 : 로컬레퍼지토리에 반영

6.git push origin master

- ->푸쉬를 진행하겠습니다
- ->원격저장소로 커밋한 내용을 올려주세요

7. git pull origin master

잘못입력시 전에 입력한 값확인
git config --global --list

git remote -v //원격장소를 확인하는 방법

git add . 커밋 준비

**git config --global --list 입력정보확인**

**git remote -v 원격저장소 주소 확인**

git commit -m

//-은 옵션이라는 뜻이고 m은 message의 약자

git push origin master
rm = remove 
git remote rm 지우고 싶은 원격장소이름

# %%
cd HTML
cd gitTest
git init
git config --giobal user.name ""
git config --giobal user.email ""
git remote add origin 원격저장소 주소
git pull origin master

# %%
보완때문에 로컬 레포지토리 따로 만듬
이거에 push하고 pull
아무리 많이 push 한다고 해도 오류 나지 않음 어쩃든 내려받는 거니까

# %%
git을 위한 폴더 하나 만들고 여기에 명령어 실행해 로컬 레포지토리와 연결

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
여기가 경로 그래서 여기에서 새로운 곳으로 가야함

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
이렿게 경로 바뀜

# %%
git init

# %%
이 깃허브와 이 폴더를 연결한다 = 이 폴더를 로컬 레포지토리화 시킨다
git init 
git push 와 git pull이 가능하도록 로컬레포지토리화 시킨다

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
add .  이경로에 있는 모든 내용

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
팀장이 올리면 팀원이 git pull orign master 하고 수정해서 올리기
만약 내가 바로 하고 싶으면 풀하면 이미 올레디 띠니까 그냘 바로 수정하고 올리기

# %%
commit 하고 push하면 내가 올리게 된다 이걸 남이 올리고 싶으면 먼저 pull한 다음에 수정하고 add.하기
커밋하고 push
